# %% [markdown]
# ## Install packages

# %%
# !cat /proc/cpuinfo | grep model\ name
import torch
torch.cuda.get_device_name(0)
# Out:
# model name	: Intel(R) Xeon(R) CPU @ 2.30GHz
# model name	: Intel(R) Xeon(R) CPU @ 2.30GHz
# model name	: Intel(R) Xeon(R) CPU @ 2.30GHz
# model name	: Intel(R) Xeon(R) CPU @ 2.30GHz
# 'Tesla P100-PCIE-16GB'

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# %cd ..
# !rm -rf CryptenTest
# clone the repo
# !git clone https://github.com/Freedomeri/CryptenTest.git
# %cd CryptenTest/
# Out:
# /
# Cloning into 'CryptenTest'...
# remote: Enumerating objects: 1162, done.
# remote: Counting objects: 100% (283/283), done.
# remote: Compressing objects: 100% (149/149), done.
# remote: Total 1162 (delta 155), reused 247 (delta 127), pack-reused 879
# Receiving objects: 100% (1162/1162), 194.38 MiB | 16.59 MiB/s, done.
# Resolving deltas: 100% (489/489), done.
# Checking out files: 100% (572/572), done.
# /CryptenTest

# %%
# install requirements
# !pip install -r requirements.txt
# if the above command does not work:
#!pip install transformers==3.0.2
#!pip install tensorboardX==2.0
#pip install omegaconf==2.1.1
#!pip install onnx==1.10.2
#!pip install tokenizers==0.8.1rc1
#!pip install sentencepiece==0.1.85
#!pip install sacremoses==0.0.45
#!pip install jsonlines
# !pip install https://download.pytorch.org/whl/cu111/torch-1.8.1%2Bcu111-cp38-cp38-linux_x86_64.whl
# %cd ..

import nltk
nltk.download('stopwords')

#install fp16 optimization
# !git clone https://github.com/timmoon10/apex.git
# %cd apex
# !pip install -v --no-cache-dir ./
# %cd ..
# !pip install https://github.com/explosion/spacy-models/releases/download/en_core_web_lg-2.2.5/en_core_web_lg-2.2.5.tar.gz
# some issue with colab
# !pip install --upgrade "urllib3==1.25.4" awscli
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      |████████████████████████████████| 23.4 MB 1.1 MB/s
# ...
#      |████████████████████████████████| 15.7 MB 5.7 MB/s
# ...
#      |████████████████████████████████| 705 kB 90.0 MB/s
# ...
#      |████████████████████████████████| 25.2 MB 1.3 MB/s
# ...
#      |████████████████████████████████| 1.0 MB 66.9 MB/s
# ...
#      |████████████████████████████████| 195 kB 90.5 MB/s
# ...
#      |████████████████████████████████| 56 kB 5.3 MB/s
# ...
#      |████████████████████████████████| 1.4 MB 73.3 MB/s
# ...
#      |████████████████████████████████| 74 kB 151 kB/s
# ...
#      |████████████████████████████████| 12.7 MB 70.5 MB/s
# ...
#      |████████████████████████████████| 3.0 MB 60.5 MB/s
# ...
#      |████████████████████████████████| 895 kB 87.0 MB/s
# ...
#      |████████████████████████████████| 10.3 MB 11.9 MB/s
# ...
#      |████████████████████████████████| 112 kB 82.7 MB/s
# ...
#      |████████████████████████████████| 211 kB 82.1 MB/s
# ...

# %%
# %cd ..
# Out:
# /

# %%
# %cd CryptenTest/
# Out:
# /CryptenTest

# %%
# !ls
# Out:
# blocked_index.csv	 input		     run_all_er_magellan.py
# blocking		 LICENSE	     run_all_vary_size.py
# configs			 log.txt	     run_all_wdc.py
# configs.json		 matcher_old.py      Snippext_public
# crypten			 models		     TestBloom.py
# crypten-0.4.0.dist-info  MyBertModel.py      testoutput.txt
# data			 output		     test.py
# ditto			 params.txt	     train_ditto.py
# ditto.jpg		 Plaintext_train.py  transformers
# encrypted_data		 README.md	     transformers-3.0.2.dist-info
# examples		 requirements.txt    Two_parties_infer.py
# Infer_test.py		 results_ditto

# %%
# !CUDA_VISIBLE_DEVICES=0 python Plaintext_train.py \
  --task Textual_Abt-Buy \
  --hidden_size 768 \
  --batch_size 16 \
  --max_len 256 \
  --n_epochs 40 \
  --lr 3e-5 \
  --lm bert \
  --bert_path "models/bert-base" \
  --summarize \
  --dk product \
  --da del \
  --finetuning \
  --save_model

# !cp -rf /CryptenTest/*dev.pt /content/drive/MyDrive/saved/
# Out:
# Downloading: 100% 232k/232k [00:00<00:00, 258kB/s]
# /usr/local/lib/python3.8/dist-packages/torch/nn/functional.py:1709: UserWarning: nn.functional.sigmoid is deprecated. Use torch.sigmoid instead.
#   warnings.warn("nn.functional.sigmoid is deprecated. Use torch.sigmoid instead.")
# =====sanity check======
# words: COL name PRODUCT VAL samsung 19 ' black flat panel series 6 lcd hdtv ID ln19a650 COL description VAL 1440 x 900 true 720p resolution ID 3,000:1 dynamic contrast ratio srs trusurround xt built - in digital tuner ( atsc / clear qam ) wide color enhancer 8ms response time touch of design with red finish COL price VAL 499 [SEP] COL name PRODUCT VAL samsung 9 series ID ln55a950 NUM 55 ' lcd tv COL description VAL atsc , PRODUCT ntsc 181 channels 16:9 NUM 1920 x 1080 surround hdtv 1080p COL price VAL 4049.98
# x: [  101  8902  2171  4031 11748 19102  2539  1005  2304  4257  5997  2186
#   1020 27662 10751  9189  8909  1048  2078 16147  2050 26187  2692  8902
# ...

# %%
# !pip install https://download.pytorch.org/whl/cu111/torch-1.8.1%2Bcu111-cp38-cp38-linux_x86_64.whl
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      |█████████████▌                  | 834.1 MB 1.2 MB/s eta 0:16:13tcmalloc: large alloc 1147494400 bytes == 0x3b9e000 @  0x7f33205ee615 0x5d631c 0x51e4f1 0x51e67b 0x4f7585 0x49ca7c 0x4fdff5 0x49caa1 0x4fdff5 0x49ced5 0x4f60a9 0x55f926 0x4f60a9 0x55f926 0x4f60a9 0x55f926 0x5d7c18 0x5d9412 0x586636 0x5d813c 0x55f3fd 0x55e571 0x5d7cf1 0x49ced5 0x55e571 0x5d7cf1 0x49ec69 0x5d7c18 0x49ca7c 0x4fdff5 0x49ced5
#      |█████████████████               | 1055.7 MB 1.1 MB/s eta 0:13:36tcmalloc: large alloc 1434370048 bytes == 0x481f4000 @  0x7f33205ee615 0x5d631c 0x51e4f1 0x51e67b 0x4f7585 0x49ca7c 0x4fdff5 0x49caa1 0x4fdff5 0x49ced5 0x4f60a9 0x55f926 0x4f60a9 0x55f926 0x4f60a9 0x55f926 0x5d7c18 0x5d9412 0x586636 0x5d813c 0x55f3fd 0x55e571 0x5d7cf1 0x49ced5 0x55e571 0x5d7cf1 0x49ec69 0x5d7c18 0x49ca7c 0x4fdff5 0x49ced5
# ...

# %%
# !CUDA_VISIBLE_DEVICES=0 python Two_parties_infer.py
# Out:
# WARNING:transformers.modeling_utils:Some weights of the model checkpoint at models/bert-base-finetuned-beer were not used when initializing MyBERTModel: ['bert.embeddings.word_embeddings.weight', 'bert.embeddings.position_embeddings.weight', 'bert.embeddings.token_type_embeddings.weight', 'bert.embeddings.LayerNorm.weight', 'bert.embeddings.LayerNorm.bias']
# - This IS expected if you are initializing MyBERTModel from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPretraining model).
# - This IS NOT expected if you are initializing MyBERTModel from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# 10it [00:00, 54755.93it/s]
# /usr/local/lib/python3.7/dist-packages/torch/nn/functional.py:1709: UserWarning: nn.functional.sigmoid is deprecated. Use torch.sigmoid instead.
# ...

# %%
import spacy
print(spacy.__version__)
# !pip install spacy==2.2.3
# Out:
# 2.2.3
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
import shutil
# 把olddir拷贝一份newdir
#shutil.copytree('content/drive/MyDrive/bert-base-finetuned', 'CryptenTest/models/bert-base-finetuned-beer')
shutil.copytree('content/drive/MyDrive/Company', 'CryptenTest/data/er_magellan/Textual/Company')
# Out:
# 'CryptenTest/data/er_magellan/Textual/Company'

# %%
# !pip install scipy==1.5.0
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      |████████████████████████████████| 25.7 MB 1.2 MB/s
# ...
#   Attempting uninstall: scipy
#     Found existing installation: scipy 1.3.2
#     Uninstalling scipy-1.3.2:
#       Successfully uninstalled scipy-1.3.2
# ...

# %%
import shutil
# 把olddir拷贝一份newdir
#shutil.copytree('content/drive/MyDrive/bert-base-finetuned', 'CryptenTest/models/bert-base-finetuned-beer')
shutil.copytree('content/drive/MyDrive/bert-base', 'CryptenTest/models/bert-base')
# Out:
# 'CryptenTest/models/bert-base'

# %%
# !ngrok authtoken 2DmqSsNBfFsHKvgffB9cDMiGUyG_wAYh9vaUavAoAcuvTwQ1
# Out:
# Authtoken saved to configuration file: /root/.ngrok2/ngrok.yml

# %%
 #vscode
 #!pip install colabcode
 from colabcode import ColabCode
 ColabCode(port=10000)
# Out:
# Code Server can be accessed on: NgrokTunnel: "https://60d1-35-189-189-136.ngrok.io" -> "http://localhost:10000"
# [2022-10-01T14:04:17.066Z] info  code-server 3.10.2 387b12ef4ca404ffd39d84834e1f0776e9e3c005
# [2022-10-01T14:04:17.067Z] info  Using user-data-dir ~/.local/share/code-server
# [2022-10-01T14:04:17.082Z] info  Using config file ~/.config/code-server/config.yaml
# [2022-10-01T14:04:17.082Z] info  HTTP server listening on http://127.0.0.1:10000
# [2022-10-01T14:04:17.082Z] info    - Authentication is disabled
# [2022-10-01T14:04:17.082Z] info    - Not serving HTTPS
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-11-01773564ec97> in <module>
#       1 from colabcode import ColabCode
# ----> 2 ColabCode(port=10000)
#
# /usr/local/lib/python3.7/dist-packages/colabcode/code.py in __init__(self, port, password, authtoken, mount_drive, code, lab)
# ...

# %% [markdown]
# ## Running the matcher

# %%
# !CUDA_VISIBLE_DEVICES=0 python matcher_old.py \
  --task Structured_Beer \
  --input_path input/input_beer_10.txt \
  --output_path output/output_beer_10.jsonl \
  --lm bert \
  --max_len 128 \
  --use_gpu \
  --checkpoint_path models/bert-base-finetuned-beer
# Out:
# 10it [00:00, 56603.29it/s]

# %%
# !git clone https://github.com/timmoon10/apex.git
# %cd apex
# !pip install -v --no-cache-dir ./
# Out:
# fatal: destination path 'apex' already exists and is not an empty directory.
# /apex
# Using pip 21.1.3 from /usr/local/lib/python3.8/dist-packages/pip (python 3.8)
# Value for scheme.platlib does not match. Please report this to <https://github.com/pypa/pip/issues/9617>
# distutils: /usr/local/lib/python3.8/dist-packages
# sysconfig: /usr/lib/python3.8/site-packages
# Value for scheme.purelib does not match. Please report this to <https://github.com/pypa/pip/issues/9617>
# distutils: /usr/local/lib/python3.8/dist-packages
# sysconfig: /usr/lib/python3.8/site-packages
# Value for scheme.headers does not match. Please report this to <https://github.com/pypa/pip/issues/9617>
# distutils: /usr/local/include/python3.8/UNKNOWN
# sysconfig: /usr/include/python3.8/UNKNOWN
# Value for scheme.scripts does not match. Please report this to <https://github.com/pypa/pip/issues/9617>
# distutils: /usr/local/bin
# sysconfig: /usr/bin
# ...
